# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# import CSV of Cleaned data and create DF
df = pd.read_csv("MastersWinners.csv")
df = df.drop(columns='Unnamed: 0')
df.head()
cluster_df = df.drop(columns=['Player Name', 'Season'])
cluster_df.head()
number_of_rows = len(cluster_df.index)
print(number_of_rows)
cluster_df.head()
# Out:
# 11223
#    Accuracy Rating - (RATING)  Scoring Rating - (RATING)  \
# 0                         6.3                    7.84506
# 1                         5.5                    8.00000
# 2                         6.0                    8.20000
# 3                         6.1                    8.00000
# 4                         5.5                    8.20000
#
#    Power Rating - (RATING)  Putting Rating - (RATING)  \
# 0                      7.1                   7.740683
# 1                      8.7                   8.200000
# 2                      8.0                   8.100000
# 3                      7.5                   8.400000
# 4                      6.8                   8.600000
#
#    Short Game Rating - (RATING)  Label
# 0                           5.1      0
# 1                           6.4      0
# 2                           7.0      0
# 3                           6.6      0
# 4                           6.7      0

# %%
print(cluster_df.columns.values)
# Out:
# ['Accuracy Rating - (RATING)' 'Scoring Rating - (RATING)'
#  'Power Rating - (RATING)' 'Putting Rating - (RATING)'
#  'Short Game Rating - (RATING)' 'Label']

# %%
print(cluster_df.isna().sum())
# Out:
# Accuracy Rating - (RATING)      0
# Scoring Rating - (RATING)       0
# Power Rating - (RATING)         0
# Putting Rating - (RATING)       0
# Short Game Rating - (RATING)    0
# Label                           0
# dtype: int64

# %%
# Create X variable for cluster data
from sklearn.datasets.samples_generator import make_blobs

X = np.array(cluster_df.astype(float))

# %%
print(X)
# Out:
# [[6.3        7.84506024 7.1        7.74068273 5.1        0.        ]
#  [5.5        8.         8.7        8.2        6.4        0.        ]
#  [6.         8.2        8.         8.1        7.         0.        ]
#  ...
#  [6.70630003 7.84506024 5.93962396 7.74068273 6.19731164 0.        ]
#  [6.70630003 7.84506024 5.93962396 7.74068273 6.19731164 0.        ]
#  [6.70630003 7.84506024 5.93962396 7.74068273 6.19731164 0.        ]]

# %%
# Plot and show scatter
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)

# Fit the model to the data
kmeans.fit(X)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = kmeans.predict(X)

# %%
# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
# Print the cluster centers and cluster labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[6.70759163e+00, 7.84474025e+00, 5.93481782e+00, 7.73932120e+00,
#         6.19731591e+00, 2.42156243e-03],
#        [6.72373737e+00, 7.69837167e+00, 3.41388889e+00, 7.77363733e+00,
#         6.32848104e+00, 3.78787879e-03],
#        [6.67834941e+00, 7.97283798e+00, 8.13258307e+00, 7.72656887e+00,
#         6.08592181e+00, 4.39442658e-02]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.show()

# %%
sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(X)
    sum_of_squared_distances.append(km.inertia_)
    
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()
